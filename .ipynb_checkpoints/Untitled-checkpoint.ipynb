# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import torch
import torch.nn as nn
import torch.optim as optim
import yfinance as yf

# %%
# Download historical data for Apple stock
stock_data = yf.download('GOOG', start='2010-01-01', end='2024-01-01')
stock_data = stock_data[['Close']]  # We are only interested in the 'Close' price
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/abinshoby/miniforge3/envs/tf_new/lib/python3.10/site-packages/yfinance/utils.py:771: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')

# %%
# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(stock_data.values)

# Function to create dataset with time steps
def create_dataset(data, time_step=60):
    X, y = [], []
    for i in range(time_step, len(data)):
        X.append(data[i-time_step:i, 0])  # past `time_step` prices as input
        y.append(data[i, 0])  # future price as output
    return np.array(X), np.array(y)

# Split into train and test datasets
training_data_len = int(len(scaled_data) * 0.8)
train_data = scaled_data[:training_data_len]
test_data = scaled_data[training_data_len - 60:]

# Create datasets
X_train, y_train = create_dataset(train_data)
X_test, y_test = create_dataset(test_data)

# %%
# Convert the data to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# Reshape X data for LSTM input
X_train = X_train.unsqueeze(2)  # Shape: (samples, time steps, features)
X_test = X_test.unsqueeze(2)    # Shape: (samples, time steps, features)

# %%
class StockPredictionRNN(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=50, output_size=1):
        super(StockPredictionRNN, self).__init__()
        # LSTM layer
        self.lstm = nn.LSTM(input_size, hidden_layer_size, batch_first=True)
        # Fully connected layer
        self.fc = nn.Linear(hidden_layer_size, output_size)
    
    def forward(self, x):
        # Pass through LSTM layer
        lstm_out, (h_n, c_n) = self.lstm(x)
        # Get the output of the last time step
        out = self.fc(lstm_out[:, -1, :])
        return out

# %%
# Initialize the model, loss function, and optimizer
model = StockPredictionRNN()
criterion = nn.MSELoss()  # Mean Squared Error Loss for regression
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    
    # Zero gradients
    optimizer.zero_grad()
    
    # Forward pass
    output = model(X_train)
    
    # Compute loss
    loss = criterion(output, y_train.view(-1, 1))
    
    # Backward pass and optimization
    loss.backward()
    optimizer.step()
    
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/100], Loss: 0.0236
# Epoch [20/100], Loss: 0.0220
# Epoch [30/100], Loss: 0.0193
# Epoch [40/100], Loss: 0.0156
# Epoch [50/100], Loss: 0.0070
# Epoch [60/100], Loss: 0.0016
# Epoch [70/100], Loss: 0.0006
# Epoch [80/100], Loss: 0.0002
# Epoch [90/100], Loss: 0.0001
# Epoch [100/100], Loss: 0.0001

# %%
# Switch to evaluation mode
model.eval()

# Make predictions on test data
with torch.no_grad():
    test_predictions = model(X_test)

# Invert normalization for actual and predicted values
y_test = y_test.view(-1, 1)
predicted_prices = scaler.inverse_transform(test_predictions.numpy())
actual_prices = scaler.inverse_transform(y_test.numpy())

# Plot the predictions vs actual values
plt.figure(figsize=(10, 6))
plt.plot(actual_prices, color='blue', label='Actual Stock Price')
plt.plot(predicted_prices, color='red', label='Predicted Stock Price')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Get the last 60 days of stock data for prediction
input_data = scaled_data[-60:]
input_data = torch.tensor(input_data, dtype=torch.float32).unsqueeze(0).unsqueeze(2)

# Get the model's prediction
with torch.no_grad():
    predicted_price = model(input_data[0])

# Invert normalization to get the actual predicted price
predicted_price = scaler.inverse_transform(predicted_price.numpy())
print(f"Predicted Price: {predicted_price[0][0]}")
# Out:
# Predicted Price: 27.691329956054688

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
import torch.optim as optim
import yfinance as yf

# Fetch and preprocess data
data = yf.download('AAPL', start='2010-01-01', end='2024-01-01')['Close'].values.reshape(-1, 1)

# Normalize data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Create dataset
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(time_step, len(data)):
        X.append(data[i-time_step:i])
        y.append(data[i])
    return np.array(X), np.array(y)

time_step = 30
X, y = create_dataset(scaled_data, time_step)
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)

# Split data into training and test sets
train_size = int(len(X) * 0.8)
train_X, test_X = X[:train_size], X[train_size:]
train_y, test_y = y[:train_size], y[train_size:]

# Model definitions
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        out, _ = self.rnn(x)
        out = self.fc(out[:, -1, :])
        return out

class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(GRUModel, self).__init__()
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        out, _ = self.gru(x)
        out = self.fc(out[:, -1, :])
        return out

# Train and evaluate model with cross-validation
def train_model(model_class, model_name, params, X, y, n_splits=3):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    results = []
    train_losses, val_losses = [], []
    best_models = []
    
    for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
        print(f"\nTraining {model_name} - Hidden Size: {params['hidden_size']}, "
              f"Num Layers: {params['num_layers']}, Learning Rate: {params['learning_rate']} - Fold {fold + 1}")

        train_X, val_X = X[train_idx], X[val_idx]
        train_y, val_y = y[train_idx], y[val_idx]

        model = model_class(input_size=1, hidden_size=params['hidden_size'], 
                            num_layers=params['num_layers'], output_size=1)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=params['learning_rate'])

        best_val_loss = float('inf')
        early_stop_count = 0
        fold_train_loss, fold_val_loss = [], []

        for epoch in range(100):
            model.train()
            optimizer.zero_grad()
            output = model(train_X)
            loss = criterion(output, train_y.view(-1, 1))
            loss.backward()
            optimizer.step()
            fold_train_loss.append(loss.item())

            model.eval()
            with torch.no_grad():
                val_output = model(val_X)
                val_loss = criterion(val_output, val_y.view(-1, 1)).item()
                fold_val_loss.append(val_loss)

            # Print training progress
            print(f"    Epoch {epoch+1}: Train Loss: {loss.item():.4f}, Val Loss: {val_loss:.4f}")

            # Early stopping and saving best model
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state = model.state_dict()  # Save the best model weights
                early_stop_count = 0
            else:
                early_stop_count += 1

            if early_stop_count > 10:
                print(f"    Early stopping at epoch {epoch+1}")
                break

        train_losses.append(fold_train_loss)
        val_losses.append(fold_val_loss)
        val_rmse = np.sqrt(best_val_loss)
        results.append({'Fold': fold + 1, 'Val_RMSE': val_rmse})
        best_models.append(best_model_state)

    return results, train_losses, val_losses, best_models

# Hyperparameter grid
hidden_sizes = [16,] #32]
num_layers_list = [1,] #2]
learning_rates = [0.001,] #0.01]

# Store results
final_results = []

for model_class, model_name in zip([RNNModel, LSTMModel, GRUModel], ['RNN', 'LSTM', 'GRU']):
    for hidden_size in hidden_sizes:
        for num_layers in num_layers_list:
            for lr in learning_rates:
                params = {'hidden_size': hidden_size, 'num_layers': num_layers, 'learning_rate': lr}
                results, train_losses, val_losses, best_models = train_model(model_class, model_name, params, train_X, train_y)
                avg_rmse = np.mean([r['Val_RMSE'] for r in results])
                final_results.append({
                    'Model': model_name,
                    'Hidden_Size': hidden_size,
                    'Num_Layers': num_layers,
                    'Learning_Rate': lr,
                    'Avg_Val_RMSE': avg_rmse,
                    'Best_Models': best_models,
                    'Train_Loss': train_losses,
                    'Val_Loss': val_losses
                })

# Store results in a DataFrame
results_df = pd.DataFrame(final_results)

# Test each model and plot predictions
plt.figure(figsize=(12, 8))
actual_prices = scaler.inverse_transform(test_y.numpy().reshape(-1, 1))

for model_name, model_class in zip(['RNN', 'LSTM', 'GRU'], [RNNModel, LSTMModel, GRUModel]):
    # Filter the best parameters for this model
    model_results = results_df[results_df['Model'] == model_name]
    best_row = model_results.loc[model_results['Avg_Val_RMSE'].idxmin()]
    best_params = {
        'hidden_size': best_row['Hidden_Size'],
        'num_layers': best_row['Num_Layers'],
        'learning_rate': best_row['Learning_Rate']
    }
    best_weights = best_row['Best_Models'][0]  # Load the best model weights for the first fold
    
    # Initialize and load the model
    best_model = model_class(input_size=1, hidden_size=int(best_params['hidden_size']),
                             num_layers=int(best_params['num_layers']), output_size=1)
    best_model.load_state_dict(best_weights)
    
    # Evaluate on the test set
    best_model.eval()
    with torch.no_grad():
        test_output = best_model(test_X)
        predicted_prices = scaler.inverse_transform(test_output.numpy())
    
    # Calculate RMSE for test set
    criterion = nn.MSELoss()
    test_rmse = np.sqrt(criterion(test_output, test_y.view(-1, 1)).item())
    print(f"Test RMSE for {model_name}: {test_rmse:.4f}")
    
    # Plot the predictions
    plt.plot(predicted_prices, label=f'{model_name} Predictions (RMSE: {test_rmse:.4f})')

# Plot actual prices
plt.plot(actual_prices, label='Actual Prices', color='blue', linewidth=2)

# Customize the plot
plt.title('Test Data: Actual vs Predicted Prices for RNN, LSTM, GRU')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.grid()
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# /Users/abinshoby/miniforge3/envs/tf_new/lib/python3.10/site-packages/yfinance/utils.py:771: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# Training RNN - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 1
#     Epoch 1: Train Loss: 0.0239, Val Loss: 0.0235
#     Epoch 2: Train Loss: 0.0235, Val Loss: 0.0232
#     Epoch 3: Train Loss: 0.0232, Val Loss: 0.0229
#     Epoch 4: Train Loss: 0.0228, Val Loss: 0.0225
#     Epoch 5: Train Loss: 0.0224, Val Loss: 0.0221
#     Epoch 6: Train Loss: 0.0221, Val Loss: 0.0218
#     Epoch 7: Train Loss: 0.0217, Val Loss: 0.0214
#     Epoch 8: Train Loss: 0.0214, Val Loss: 0.0211
#     Epoch 9: Train Loss: 0.0210, Val Loss: 0.0207
#     Epoch 10: Train Loss: 0.0207, Val Loss: 0.0203
#     Epoch 11: Train Loss: 0.0203, Val Loss: 0.0200
#     Epoch 12: Train Loss: 0.0200, Val Loss: 0.0196
#     Epoch 13: Train Loss: 0.0196, Val Loss: 0.0193
#     Epoch 14: Train Loss: 0.0192, Val Loss: 0.0189
#     Epoch 15: Train Loss: 0.0188, Val Loss: 0.0185
#     Epoch 16: Train Loss: 0.0184, Val Loss: 0.0181
#     Epoch 17: Train Loss: 0.0180, Val Loss: 0.0177
#     Epoch 18: Train Loss: 0.0176, Val Loss: 0.0172
#     Epoch 19: Train Loss: 0.0172, Val Loss: 0.0168
#     Epoch 20: Train Loss: 0.0167, Val Loss: 0.0163
#     Epoch 21: Train Loss: 0.0163, Val Loss: 0.0158
#     Epoch 22: Train Loss: 0.0158, Val Loss: 0.0153
#     Epoch 23: Train Loss: 0.0152, Val Loss: 0.0147
#     Epoch 24: Train Loss: 0.0147, Val Loss: 0.0141
#     Epoch 25: Train Loss: 0.0140, Val Loss: 0.0134
#     Epoch 26: Train Loss: 0.0134, Val Loss: 0.0127
#     Epoch 27: Train Loss: 0.0127, Val Loss: 0.0120
#     Epoch 28: Train Loss: 0.0119, Val Loss: 0.0111
#     Epoch 29: Train Loss: 0.0111, Val Loss: 0.0102
#     Epoch 30: Train Loss: 0.0102, Val Loss: 0.0092
#     Epoch 31: Train Loss: 0.0091, Val Loss: 0.0081
#     Epoch 32: Train Loss: 0.0080, Val Loss: 0.0069
#     Epoch 33: Train Loss: 0.0068, Val Loss: 0.0056
#     Epoch 34: Train Loss: 0.0056, Val Loss: 0.0043
#     Epoch 35: Train Loss: 0.0042, Val Loss: 0.0030
#     Epoch 36: Train Loss: 0.0029, Val Loss: 0.0018
#     Epoch 37: Train Loss: 0.0017, Val Loss: 0.0009
#     Epoch 38: Train Loss: 0.0008, Val Loss: 0.0006
#     Epoch 39: Train Loss: 0.0005, Val Loss: 0.0011
#     Epoch 40: Train Loss: 0.0011, Val Loss: 0.0019
#     Epoch 41: Train Loss: 0.0018, Val Loss: 0.0024
#     Epoch 42: Train Loss: 0.0023, Val Loss: 0.0025
#     Epoch 43: Train Loss: 0.0025, Val Loss: 0.0020
#     Epoch 44: Train Loss: 0.0020, Val Loss: 0.0015
#     Epoch 45: Train Loss: 0.0014, Val Loss: 0.0009
#     Epoch 46: Train Loss: 0.0008, Val Loss: 0.0005
#     Epoch 47: Train Loss: 0.0005, Val Loss: 0.0003
#     Epoch 48: Train Loss: 0.0003, Val Loss: 0.0004
#     Epoch 49: Train Loss: 0.0003, Val Loss: 0.0004
#     Epoch 50: Train Loss: 0.0004, Val Loss: 0.0006
#     Epoch 51: Train Loss: 0.0005, Val Loss: 0.0007
#     Epoch 52: Train Loss: 0.0006, Val Loss: 0.0008
#     Epoch 53: Train Loss: 0.0007, Val Loss: 0.0008
#     Epoch 54: Train Loss: 0.0008, Val Loss: 0.0008
#     Epoch 55: Train Loss: 0.0008, Val Loss: 0.0008
#     Epoch 56: Train Loss: 0.0007, Val Loss: 0.0007
#     Epoch 57: Train Loss: 0.0006, Val Loss: 0.0006
#     Epoch 58: Train Loss: 0.0005, Val Loss: 0.0005
#     Early stopping at epoch 58
#
# Training RNN - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 2
#     Epoch 1: Train Loss: 0.3791, Val Loss: 0.3584
#     Epoch 2: Train Loss: 0.3626, Val Loss: 0.3427
#     Epoch 3: Train Loss: 0.3468, Val Loss: 0.3275
#     Epoch 4: Train Loss: 0.3315, Val Loss: 0.3128
#     Epoch 5: Train Loss: 0.3168, Val Loss: 0.2987
#     Epoch 6: Train Loss: 0.3026, Val Loss: 0.2852
#     Epoch 7: Train Loss: 0.2890, Val Loss: 0.2721
#     Epoch 8: Train Loss: 0.2758, Val Loss: 0.2595
#     Epoch 9: Train Loss: 0.2632, Val Loss: 0.2473
#     Epoch 10: Train Loss: 0.2509, Val Loss: 0.2356
#     Epoch 11: Train Loss: 0.2391, Val Loss: 0.2243
#     Epoch 12: Train Loss: 0.2278, Val Loss: 0.2133
#     Epoch 13: Train Loss: 0.2168, Val Loss: 0.2028
#     Epoch 14: Train Loss: 0.2062, Val Loss: 0.1926
#     Epoch 15: Train Loss: 0.1959, Val Loss: 0.1828
#     Epoch 16: Train Loss: 0.1860, Val Loss: 0.1732
#     Epoch 17: Train Loss: 0.1764, Val Loss: 0.1640
#     Epoch 18: Train Loss: 0.1671, Val Loss: 0.1551
#     Epoch 19: Train Loss: 0.1582, Val Loss: 0.1464
#     Epoch 20: Train Loss: 0.1494, Val Loss: 0.1381
#     Epoch 21: Train Loss: 0.1410, Val Loss: 0.1300
#     Epoch 22: Train Loss: 0.1329, Val Loss: 0.1221
#     Epoch 23: Train Loss: 0.1250, Val Loss: 0.1146
#     Epoch 24: Train Loss: 0.1173, Val Loss: 0.1072
#     Epoch 25: Train Loss: 0.1100, Val Loss: 0.1002
#     Epoch 26: Train Loss: 0.1029, Val Loss: 0.0934
#     Epoch 27: Train Loss: 0.0961, Val Loss: 0.0869
#     Epoch 28: Train Loss: 0.0895, Val Loss: 0.0807
#     Epoch 29: Train Loss: 0.0832, Val Loss: 0.0748
#     Epoch 30: Train Loss: 0.0772, Val Loss: 0.0691
#     Epoch 31: Train Loss: 0.0715, Val Loss: 0.0638
#     Epoch 32: Train Loss: 0.0661, Val Loss: 0.0587
#     Epoch 33: Train Loss: 0.0610, Val Loss: 0.0540
#     Epoch 34: Train Loss: 0.0562, Val Loss: 0.0496
#     Epoch 35: Train Loss: 0.0517, Val Loss: 0.0455
#     Epoch 36: Train Loss: 0.0476, Val Loss: 0.0418
#     Epoch 37: Train Loss: 0.0438, Val Loss: 0.0384
#     Epoch 38: Train Loss: 0.0404, Val Loss: 0.0354
#     Epoch 39: Train Loss: 0.0374, Val Loss: 0.0328
#     Epoch 40: Train Loss: 0.0347, Val Loss: 0.0305
#     Epoch 41: Train Loss: 0.0323, Val Loss: 0.0286
#     Epoch 42: Train Loss: 0.0304, Val Loss: 0.0270
#     Epoch 43: Train Loss: 0.0288, Val Loss: 0.0258
#     Epoch 44: Train Loss: 0.0275, Val Loss: 0.0250
#     Epoch 45: Train Loss: 0.0266, Val Loss: 0.0244
#     Epoch 46: Train Loss: 0.0260, Val Loss: 0.0241
#     Epoch 47: Train Loss: 0.0256, Val Loss: 0.0240
#     Epoch 48: Train Loss: 0.0255, Val Loss: 0.0240
#     Epoch 49: Train Loss: 0.0255, Val Loss: 0.0242
#     Epoch 50: Train Loss: 0.0257, Val Loss: 0.0245
#     Epoch 51: Train Loss: 0.0259, Val Loss: 0.0248
#     Epoch 52: Train Loss: 0.0262, Val Loss: 0.0251
#     Epoch 53: Train Loss: 0.0265, Val Loss: 0.0253
#     Epoch 54: Train Loss: 0.0267, Val Loss: 0.0255
#     Epoch 55: Train Loss: 0.0269, Val Loss: 0.0256
#     Epoch 56: Train Loss: 0.0270, Val Loss: 0.0257
#     Epoch 57: Train Loss: 0.0270, Val Loss: 0.0256
#     Epoch 58: Train Loss: 0.0269, Val Loss: 0.0254
#     Early stopping at epoch 58
#
# Training RNN - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 3
#     Epoch 1: Train Loss: 0.0335, Val Loss: 0.0327
#     Epoch 2: Train Loss: 0.0312, Val Loss: 0.0307
#     Epoch 3: Train Loss: 0.0292, Val Loss: 0.0289
#     Epoch 4: Train Loss: 0.0275, Val Loss: 0.0274
#     Epoch 5: Train Loss: 0.0260, Val Loss: 0.0262
#     Epoch 6: Train Loss: 0.0248, Val Loss: 0.0253
#     Epoch 7: Train Loss: 0.0239, Val Loss: 0.0246
#     Epoch 8: Train Loss: 0.0232, Val Loss: 0.0241
#     Epoch 9: Train Loss: 0.0227, Val Loss: 0.0237
#     Epoch 10: Train Loss: 0.0224, Val Loss: 0.0236
#     Epoch 11: Train Loss: 0.0223, Val Loss: 0.0235
#     Epoch 12: Train Loss: 0.0222, Val Loss: 0.0235
#     Epoch 13: Train Loss: 0.0222, Val Loss: 0.0235
#     Epoch 14: Train Loss: 0.0222, Val Loss: 0.0235
#     Epoch 15: Train Loss: 0.0222, Val Loss: 0.0234
#     Epoch 16: Train Loss: 0.0222, Val Loss: 0.0233
#     Epoch 17: Train Loss: 0.0221, Val Loss: 0.0231
#     Epoch 18: Train Loss: 0.0219, Val Loss: 0.0229
#     Epoch 19: Train Loss: 0.0217, Val Loss: 0.0226
#     Epoch 20: Train Loss: 0.0214, Val Loss: 0.0223
#     Epoch 21: Train Loss: 0.0211, Val Loss: 0.0220
#     Epoch 22: Train Loss: 0.0208, Val Loss: 0.0217
#     Epoch 23: Train Loss: 0.0205, Val Loss: 0.0214
#     Epoch 24: Train Loss: 0.0202, Val Loss: 0.0211
#     Epoch 25: Train Loss: 0.0200, Val Loss: 0.0209
#     Epoch 26: Train Loss: 0.0197, Val Loss: 0.0206
#     Epoch 27: Train Loss: 0.0195, Val Loss: 0.0204
#     Epoch 28: Train Loss: 0.0193, Val Loss: 0.0203
#     Epoch 29: Train Loss: 0.0191, Val Loss: 0.0201
#     Epoch 30: Train Loss: 0.0190, Val Loss: 0.0199
#     Epoch 31: Train Loss: 0.0188, Val Loss: 0.0198
#     Epoch 32: Train Loss: 0.0187, Val Loss: 0.0196
#     Epoch 33: Train Loss: 0.0185, Val Loss: 0.0194
#     Epoch 34: Train Loss: 0.0183, Val Loss: 0.0191
#     Epoch 35: Train Loss: 0.0181, Val Loss: 0.0189
#     Epoch 36: Train Loss: 0.0178, Val Loss: 0.0186
#     Epoch 37: Train Loss: 0.0176, Val Loss: 0.0183
#     Epoch 38: Train Loss: 0.0173, Val Loss: 0.0181
#     Epoch 39: Train Loss: 0.0171, Val Loss: 0.0178
#     Epoch 40: Train Loss: 0.0168, Val Loss: 0.0175
#     Epoch 41: Train Loss: 0.0165, Val Loss: 0.0172
#     Epoch 42: Train Loss: 0.0162, Val Loss: 0.0169
#     Epoch 43: Train Loss: 0.0160, Val Loss: 0.0166
#     Epoch 44: Train Loss: 0.0157, Val Loss: 0.0163
#     Epoch 45: Train Loss: 0.0154, Val Loss: 0.0160
#     Epoch 46: Train Loss: 0.0151, Val Loss: 0.0157
#     Epoch 47: Train Loss: 0.0148, Val Loss: 0.0154
#     Epoch 48: Train Loss: 0.0145, Val Loss: 0.0150
#     Epoch 49: Train Loss: 0.0142, Val Loss: 0.0146
#     Epoch 50: Train Loss: 0.0138, Val Loss: 0.0142
#     Epoch 51: Train Loss: 0.0134, Val Loss: 0.0138
#     Epoch 52: Train Loss: 0.0130, Val Loss: 0.0133
#     Epoch 53: Train Loss: 0.0126, Val Loss: 0.0129
#     Epoch 54: Train Loss: 0.0122, Val Loss: 0.0124
#     Epoch 55: Train Loss: 0.0117, Val Loss: 0.0119
#     Epoch 56: Train Loss: 0.0113, Val Loss: 0.0114
#     Epoch 57: Train Loss: 0.0108, Val Loss: 0.0109
#     Epoch 58: Train Loss: 0.0103, Val Loss: 0.0103
#     Epoch 59: Train Loss: 0.0097, Val Loss: 0.0096
#     Epoch 60: Train Loss: 0.0091, Val Loss: 0.0090
#     Epoch 61: Train Loss: 0.0085, Val Loss: 0.0083
#     Epoch 62: Train Loss: 0.0078, Val Loss: 0.0076
#     Epoch 63: Train Loss: 0.0071, Val Loss: 0.0068
#     Epoch 64: Train Loss: 0.0064, Val Loss: 0.0060
#     Epoch 65: Train Loss: 0.0057, Val Loss: 0.0052
#     Epoch 66: Train Loss: 0.0049, Val Loss: 0.0044
#     Epoch 67: Train Loss: 0.0041, Val Loss: 0.0035
#     Epoch 68: Train Loss: 0.0033, Val Loss: 0.0027
#     Epoch 69: Train Loss: 0.0026, Val Loss: 0.0019
#     Epoch 70: Train Loss: 0.0018, Val Loss: 0.0012
#     Epoch 71: Train Loss: 0.0012, Val Loss: 0.0007
#     Epoch 72: Train Loss: 0.0007, Val Loss: 0.0004
#     Epoch 73: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 74: Train Loss: 0.0004, Val Loss: 0.0007
#     Epoch 75: Train Loss: 0.0007, Val Loss: 0.0011
#     Epoch 76: Train Loss: 0.0011, Val Loss: 0.0014
#     Epoch 77: Train Loss: 0.0015, Val Loss: 0.0015
#     Epoch 78: Train Loss: 0.0015, Val Loss: 0.0013
#     Epoch 79: Train Loss: 0.0014, Val Loss: 0.0010
#     Epoch 80: Train Loss: 0.0011, Val Loss: 0.0007
#     Epoch 81: Train Loss: 0.0008, Val Loss: 0.0005
#     Epoch 82: Train Loss: 0.0005, Val Loss: 0.0003
#     Epoch 83: Train Loss: 0.0003, Val Loss: 0.0003
#     Epoch 84: Train Loss: 0.0003, Val Loss: 0.0002
#     Epoch 85: Train Loss: 0.0002, Val Loss: 0.0003
#     Epoch 86: Train Loss: 0.0003, Val Loss: 0.0003
#     Epoch 87: Train Loss: 0.0003, Val Loss: 0.0004
#     Epoch 88: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 89: Train Loss: 0.0004, Val Loss: 0.0005
#     Epoch 90: Train Loss: 0.0005, Val Loss: 0.0005
#     Epoch 91: Train Loss: 0.0005, Val Loss: 0.0005
#     Epoch 92: Train Loss: 0.0005, Val Loss: 0.0005
#     Epoch 93: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 94: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 95: Train Loss: 0.0004, Val Loss: 0.0003
#     Early stopping at epoch 95
#
# Training LSTM - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 1
#     Epoch 1: Train Loss: 0.0654, Val Loss: 0.0630
#     Epoch 2: Train Loss: 0.0626, Val Loss: 0.0603
#     Epoch 3: Train Loss: 0.0599, Val Loss: 0.0577
#     Epoch 4: Train Loss: 0.0573, Val Loss: 0.0552
#     Epoch 5: Train Loss: 0.0548, Val Loss: 0.0528
#     Epoch 6: Train Loss: 0.0524, Val Loss: 0.0505
#     Epoch 7: Train Loss: 0.0501, Val Loss: 0.0483
#     Epoch 8: Train Loss: 0.0480, Val Loss: 0.0462
#     Epoch 9: Train Loss: 0.0459, Val Loss: 0.0443
#     Epoch 10: Train Loss: 0.0439, Val Loss: 0.0424
#     Epoch 11: Train Loss: 0.0421, Val Loss: 0.0406
#     Epoch 12: Train Loss: 0.0403, Val Loss: 0.0389
#     Epoch 13: Train Loss: 0.0387, Val Loss: 0.0373
#     Epoch 14: Train Loss: 0.0371, Val Loss: 0.0358
#     Epoch 15: Train Loss: 0.0356, Val Loss: 0.0344
#     Epoch 16: Train Loss: 0.0342, Val Loss: 0.0331
#     Epoch 17: Train Loss: 0.0329, Val Loss: 0.0319
#     Epoch 18: Train Loss: 0.0317, Val Loss: 0.0307
#     Epoch 19: Train Loss: 0.0305, Val Loss: 0.0296
#     Epoch 20: Train Loss: 0.0294, Val Loss: 0.0286
#     Epoch 21: Train Loss: 0.0285, Val Loss: 0.0277
#     Epoch 22: Train Loss: 0.0275, Val Loss: 0.0269
#     Epoch 23: Train Loss: 0.0267, Val Loss: 0.0261
#     Epoch 24: Train Loss: 0.0259, Val Loss: 0.0254
#     Epoch 25: Train Loss: 0.0252, Val Loss: 0.0247
#     Epoch 26: Train Loss: 0.0246, Val Loss: 0.0241
#     Epoch 27: Train Loss: 0.0240, Val Loss: 0.0236
#     Epoch 28: Train Loss: 0.0235, Val Loss: 0.0232
#     Epoch 29: Train Loss: 0.0231, Val Loss: 0.0228
#     Epoch 30: Train Loss: 0.0227, Val Loss: 0.0224
#     Epoch 31: Train Loss: 0.0223, Val Loss: 0.0221
#     Epoch 32: Train Loss: 0.0220, Val Loss: 0.0219
#     Epoch 33: Train Loss: 0.0218, Val Loss: 0.0216
#     Epoch 34: Train Loss: 0.0216, Val Loss: 0.0215
#     Epoch 35: Train Loss: 0.0214, Val Loss: 0.0213
#     Epoch 36: Train Loss: 0.0213, Val Loss: 0.0212
#     Epoch 37: Train Loss: 0.0212, Val Loss: 0.0211
#     Epoch 38: Train Loss: 0.0211, Val Loss: 0.0210
#     Epoch 39: Train Loss: 0.0210, Val Loss: 0.0210
#     Epoch 40: Train Loss: 0.0209, Val Loss: 0.0209
#     Epoch 41: Train Loss: 0.0209, Val Loss: 0.0209
#     Epoch 42: Train Loss: 0.0208, Val Loss: 0.0208
#     Epoch 43: Train Loss: 0.0208, Val Loss: 0.0208
#     Epoch 44: Train Loss: 0.0208, Val Loss: 0.0207
#     Epoch 45: Train Loss: 0.0207, Val Loss: 0.0207
#     Epoch 46: Train Loss: 0.0207, Val Loss: 0.0206
#     Epoch 47: Train Loss: 0.0206, Val Loss: 0.0205
#     Epoch 48: Train Loss: 0.0205, Val Loss: 0.0204
#     Epoch 49: Train Loss: 0.0204, Val Loss: 0.0204
#     Epoch 50: Train Loss: 0.0204, Val Loss: 0.0203
#     Epoch 51: Train Loss: 0.0203, Val Loss: 0.0202
#     Epoch 52: Train Loss: 0.0202, Val Loss: 0.0201
#     Epoch 53: Train Loss: 0.0201, Val Loss: 0.0200
#     Epoch 54: Train Loss: 0.0200, Val Loss: 0.0199
#     Epoch 55: Train Loss: 0.0199, Val Loss: 0.0198
#     Epoch 56: Train Loss: 0.0198, Val Loss: 0.0197
#     Epoch 57: Train Loss: 0.0197, Val Loss: 0.0196
#     Epoch 58: Train Loss: 0.0196, Val Loss: 0.0195
#     Epoch 59: Train Loss: 0.0194, Val Loss: 0.0194
#     Epoch 60: Train Loss: 0.0194, Val Loss: 0.0193
#     Epoch 61: Train Loss: 0.0193, Val Loss: 0.0192
#     Epoch 62: Train Loss: 0.0192, Val Loss: 0.0191
#     Epoch 63: Train Loss: 0.0191, Val Loss: 0.0190
#     Epoch 64: Train Loss: 0.0190, Val Loss: 0.0189
#     Epoch 65: Train Loss: 0.0189, Val Loss: 0.0188
#     Epoch 66: Train Loss: 0.0188, Val Loss: 0.0187
#     Epoch 67: Train Loss: 0.0187, Val Loss: 0.0186
#     Epoch 68: Train Loss: 0.0186, Val Loss: 0.0186
#     Epoch 69: Train Loss: 0.0185, Val Loss: 0.0185
#     Epoch 70: Train Loss: 0.0184, Val Loss: 0.0184
#     Epoch 71: Train Loss: 0.0183, Val Loss: 0.0183
#     Epoch 72: Train Loss: 0.0183, Val Loss: 0.0182
#     Epoch 73: Train Loss: 0.0182, Val Loss: 0.0181
#     Epoch 74: Train Loss: 0.0181, Val Loss: 0.0180
#     Epoch 75: Train Loss: 0.0180, Val Loss: 0.0179
#     Epoch 76: Train Loss: 0.0179, Val Loss: 0.0178
#     Epoch 77: Train Loss: 0.0178, Val Loss: 0.0177
#     Epoch 78: Train Loss: 0.0177, Val Loss: 0.0176
#     Epoch 79: Train Loss: 0.0176, Val Loss: 0.0175
#     Epoch 80: Train Loss: 0.0174, Val Loss: 0.0174
#     Epoch 81: Train Loss: 0.0173, Val Loss: 0.0173
#     Epoch 82: Train Loss: 0.0172, Val Loss: 0.0171
#     Epoch 83: Train Loss: 0.0171, Val Loss: 0.0170
#     Epoch 84: Train Loss: 0.0170, Val Loss: 0.0169
#     Epoch 85: Train Loss: 0.0169, Val Loss: 0.0168
#     Epoch 86: Train Loss: 0.0167, Val Loss: 0.0166
#     Epoch 87: Train Loss: 0.0166, Val Loss: 0.0165
#     Epoch 88: Train Loss: 0.0165, Val Loss: 0.0164
#     Epoch 89: Train Loss: 0.0164, Val Loss: 0.0162
#     Epoch 90: Train Loss: 0.0162, Val Loss: 0.0161
#     Epoch 91: Train Loss: 0.0161, Val Loss: 0.0160
#     Epoch 92: Train Loss: 0.0159, Val Loss: 0.0158
#     Epoch 93: Train Loss: 0.0158, Val Loss: 0.0157
#     Epoch 94: Train Loss: 0.0156, Val Loss: 0.0155
#     Epoch 95: Train Loss: 0.0155, Val Loss: 0.0153
#     Epoch 96: Train Loss: 0.0153, Val Loss: 0.0152
#     Epoch 97: Train Loss: 0.0151, Val Loss: 0.0150
#     Epoch 98: Train Loss: 0.0150, Val Loss: 0.0148
#     Epoch 99: Train Loss: 0.0148, Val Loss: 0.0146
#     Epoch 100: Train Loss: 0.0146, Val Loss: 0.0144
#
# Training LSTM - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 2
#     Epoch 1: Train Loss: 0.0199, Val Loss: 0.0186
#     Epoch 2: Train Loss: 0.0196, Val Loss: 0.0184
#     Epoch 3: Train Loss: 0.0195, Val Loss: 0.0182
#     Epoch 4: Train Loss: 0.0193, Val Loss: 0.0181
#     Epoch 5: Train Loss: 0.0192, Val Loss: 0.0180
#     Epoch 6: Train Loss: 0.0191, Val Loss: 0.0179
#     Epoch 7: Train Loss: 0.0190, Val Loss: 0.0178
#     Epoch 8: Train Loss: 0.0189, Val Loss: 0.0177
#     Epoch 9: Train Loss: 0.0188, Val Loss: 0.0176
#     Epoch 10: Train Loss: 0.0187, Val Loss: 0.0175
#     Epoch 11: Train Loss: 0.0185, Val Loss: 0.0173
#     Epoch 12: Train Loss: 0.0184, Val Loss: 0.0172
#     Epoch 13: Train Loss: 0.0183, Val Loss: 0.0171
#     Epoch 14: Train Loss: 0.0181, Val Loss: 0.0170
#     Epoch 15: Train Loss: 0.0180, Val Loss: 0.0168
#     Epoch 16: Train Loss: 0.0179, Val Loss: 0.0167
#     Epoch 17: Train Loss: 0.0177, Val Loss: 0.0166
#     Epoch 18: Train Loss: 0.0176, Val Loss: 0.0164
#     Epoch 19: Train Loss: 0.0174, Val Loss: 0.0162
#     Epoch 20: Train Loss: 0.0172, Val Loss: 0.0161
#     Epoch 21: Train Loss: 0.0171, Val Loss: 0.0159
#     Epoch 22: Train Loss: 0.0169, Val Loss: 0.0157
#     Epoch 23: Train Loss: 0.0167, Val Loss: 0.0156
#     Epoch 24: Train Loss: 0.0165, Val Loss: 0.0154
#     Epoch 25: Train Loss: 0.0163, Val Loss: 0.0152
#     Epoch 26: Train Loss: 0.0161, Val Loss: 0.0150
#     Epoch 27: Train Loss: 0.0159, Val Loss: 0.0148
#     Epoch 28: Train Loss: 0.0157, Val Loss: 0.0145
#     Epoch 29: Train Loss: 0.0154, Val Loss: 0.0143
#     Epoch 30: Train Loss: 0.0152, Val Loss: 0.0141
#     Epoch 31: Train Loss: 0.0149, Val Loss: 0.0138
#     Epoch 32: Train Loss: 0.0147, Val Loss: 0.0135
#     Epoch 33: Train Loss: 0.0144, Val Loss: 0.0133
#     Epoch 34: Train Loss: 0.0141, Val Loss: 0.0130
#     Epoch 35: Train Loss: 0.0138, Val Loss: 0.0127
#     Epoch 36: Train Loss: 0.0134, Val Loss: 0.0123
#     Epoch 37: Train Loss: 0.0131, Val Loss: 0.0120
#     Epoch 38: Train Loss: 0.0127, Val Loss: 0.0116
#     Epoch 39: Train Loss: 0.0123, Val Loss: 0.0112
#     Epoch 40: Train Loss: 0.0119, Val Loss: 0.0108
#     Epoch 41: Train Loss: 0.0115, Val Loss: 0.0103
#     Epoch 42: Train Loss: 0.0110, Val Loss: 0.0098
#     Epoch 43: Train Loss: 0.0105, Val Loss: 0.0093
#     Epoch 44: Train Loss: 0.0100, Val Loss: 0.0088
#     Epoch 45: Train Loss: 0.0094, Val Loss: 0.0082
#     Epoch 46: Train Loss: 0.0088, Val Loss: 0.0076
#     Epoch 47: Train Loss: 0.0081, Val Loss: 0.0070
#     Epoch 48: Train Loss: 0.0074, Val Loss: 0.0063
#     Epoch 49: Train Loss: 0.0067, Val Loss: 0.0055
#     Epoch 50: Train Loss: 0.0060, Val Loss: 0.0048
#     Epoch 51: Train Loss: 0.0052, Val Loss: 0.0040
#     Epoch 52: Train Loss: 0.0043, Val Loss: 0.0032
#     Epoch 53: Train Loss: 0.0035, Val Loss: 0.0025
#     Epoch 54: Train Loss: 0.0027, Val Loss: 0.0018
#     Epoch 55: Train Loss: 0.0020, Val Loss: 0.0011
#     Epoch 56: Train Loss: 0.0013, Val Loss: 0.0007
#     Epoch 57: Train Loss: 0.0008, Val Loss: 0.0005
#     Epoch 58: Train Loss: 0.0005, Val Loss: 0.0005
#     Epoch 59: Train Loss: 0.0006, Val Loss: 0.0008
#     Epoch 60: Train Loss: 0.0009, Val Loss: 0.0013
#     Epoch 61: Train Loss: 0.0013, Val Loss: 0.0016
#     Epoch 62: Train Loss: 0.0016, Val Loss: 0.0017
#     Epoch 63: Train Loss: 0.0017, Val Loss: 0.0016
#     Epoch 64: Train Loss: 0.0016, Val Loss: 0.0013
#     Epoch 65: Train Loss: 0.0013, Val Loss: 0.0009
#     Epoch 66: Train Loss: 0.0009, Val Loss: 0.0006
#     Epoch 67: Train Loss: 0.0006, Val Loss: 0.0004
#     Epoch 68: Train Loss: 0.0004, Val Loss: 0.0003
#     Epoch 69: Train Loss: 0.0003, Val Loss: 0.0002
#     Epoch 70: Train Loss: 0.0003, Val Loss: 0.0003
#     Epoch 71: Train Loss: 0.0003, Val Loss: 0.0003
#     Epoch 72: Train Loss: 0.0004, Val Loss: 0.0003
#     Epoch 73: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 74: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 75: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 76: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 77: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 78: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 79: Train Loss: 0.0004, Val Loss: 0.0003
#     Epoch 80: Train Loss: 0.0004, Val Loss: 0.0003
#     Early stopping at epoch 80
#
# Training LSTM - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 3
#     Epoch 1: Train Loss: 0.0279, Val Loss: 0.0278
#     Epoch 2: Train Loss: 0.0265, Val Loss: 0.0265
#     Epoch 3: Train Loss: 0.0252, Val Loss: 0.0253
#     Epoch 4: Train Loss: 0.0241, Val Loss: 0.0243
#     Epoch 5: Train Loss: 0.0231, Val Loss: 0.0234
#     Epoch 6: Train Loss: 0.0221, Val Loss: 0.0225
#     Epoch 7: Train Loss: 0.0213, Val Loss: 0.0218
#     Epoch 8: Train Loss: 0.0206, Val Loss: 0.0212
#     Epoch 9: Train Loss: 0.0200, Val Loss: 0.0207
#     Epoch 10: Train Loss: 0.0195, Val Loss: 0.0202
#     Epoch 11: Train Loss: 0.0191, Val Loss: 0.0199
#     Epoch 12: Train Loss: 0.0188, Val Loss: 0.0196
#     Epoch 13: Train Loss: 0.0185, Val Loss: 0.0194
#     Epoch 14: Train Loss: 0.0183, Val Loss: 0.0192
#     Epoch 15: Train Loss: 0.0181, Val Loss: 0.0191
#     Epoch 16: Train Loss: 0.0180, Val Loss: 0.0190
#     Epoch 17: Train Loss: 0.0179, Val Loss: 0.0189
#     Epoch 18: Train Loss: 0.0179, Val Loss: 0.0188
#     Epoch 19: Train Loss: 0.0178, Val Loss: 0.0188
#     Epoch 20: Train Loss: 0.0178, Val Loss: 0.0187
#     Epoch 21: Train Loss: 0.0177, Val Loss: 0.0186
#     Epoch 22: Train Loss: 0.0176, Val Loss: 0.0185
#     Epoch 23: Train Loss: 0.0175, Val Loss: 0.0184
#     Epoch 24: Train Loss: 0.0174, Val Loss: 0.0183
#     Epoch 25: Train Loss: 0.0173, Val Loss: 0.0181
#     Epoch 26: Train Loss: 0.0172, Val Loss: 0.0180
#     Epoch 27: Train Loss: 0.0170, Val Loss: 0.0178
#     Epoch 28: Train Loss: 0.0169, Val Loss: 0.0176
#     Epoch 29: Train Loss: 0.0167, Val Loss: 0.0175
#     Epoch 30: Train Loss: 0.0165, Val Loss: 0.0173
#     Epoch 31: Train Loss: 0.0164, Val Loss: 0.0171
#     Epoch 32: Train Loss: 0.0162, Val Loss: 0.0169
#     Epoch 33: Train Loss: 0.0160, Val Loss: 0.0168
#     Epoch 34: Train Loss: 0.0159, Val Loss: 0.0166
#     Epoch 35: Train Loss: 0.0157, Val Loss: 0.0165
#     Epoch 36: Train Loss: 0.0156, Val Loss: 0.0163
#     Epoch 37: Train Loss: 0.0154, Val Loss: 0.0162
#     Epoch 38: Train Loss: 0.0153, Val Loss: 0.0160
#     Epoch 39: Train Loss: 0.0151, Val Loss: 0.0158
#     Epoch 40: Train Loss: 0.0150, Val Loss: 0.0157
#     Epoch 41: Train Loss: 0.0148, Val Loss: 0.0155
#     Epoch 42: Train Loss: 0.0147, Val Loss: 0.0154
#     Epoch 43: Train Loss: 0.0145, Val Loss: 0.0152
#     Epoch 44: Train Loss: 0.0143, Val Loss: 0.0150
#     Epoch 45: Train Loss: 0.0142, Val Loss: 0.0148
#     Epoch 46: Train Loss: 0.0140, Val Loss: 0.0146
#     Epoch 47: Train Loss: 0.0138, Val Loss: 0.0144
#     Epoch 48: Train Loss: 0.0136, Val Loss: 0.0142
#     Epoch 49: Train Loss: 0.0134, Val Loss: 0.0140
#     Epoch 50: Train Loss: 0.0132, Val Loss: 0.0137
#     Epoch 51: Train Loss: 0.0130, Val Loss: 0.0135
#     Epoch 52: Train Loss: 0.0127, Val Loss: 0.0132
#     Epoch 53: Train Loss: 0.0125, Val Loss: 0.0130
#     Epoch 54: Train Loss: 0.0123, Val Loss: 0.0127
#     Epoch 55: Train Loss: 0.0120, Val Loss: 0.0125
#     Epoch 56: Train Loss: 0.0118, Val Loss: 0.0122
#     Epoch 57: Train Loss: 0.0115, Val Loss: 0.0119
#     Epoch 58: Train Loss: 0.0113, Val Loss: 0.0116
#     Epoch 59: Train Loss: 0.0110, Val Loss: 0.0113
#     Epoch 60: Train Loss: 0.0107, Val Loss: 0.0110
#     Epoch 61: Train Loss: 0.0104, Val Loss: 0.0107
#     Epoch 62: Train Loss: 0.0101, Val Loss: 0.0103
#     Epoch 63: Train Loss: 0.0098, Val Loss: 0.0099
#     Epoch 64: Train Loss: 0.0094, Val Loss: 0.0096
#     Epoch 65: Train Loss: 0.0091, Val Loss: 0.0092
#     Epoch 66: Train Loss: 0.0087, Val Loss: 0.0088
#     Epoch 67: Train Loss: 0.0083, Val Loss: 0.0084
#     Epoch 68: Train Loss: 0.0079, Val Loss: 0.0079
#     Epoch 69: Train Loss: 0.0075, Val Loss: 0.0075
#     Epoch 70: Train Loss: 0.0071, Val Loss: 0.0070
#     Epoch 71: Train Loss: 0.0066, Val Loss: 0.0065
#     Epoch 72: Train Loss: 0.0062, Val Loss: 0.0061
#     Epoch 73: Train Loss: 0.0057, Val Loss: 0.0056
#     Epoch 74: Train Loss: 0.0052, Val Loss: 0.0050
#     Epoch 75: Train Loss: 0.0048, Val Loss: 0.0045
#     Epoch 76: Train Loss: 0.0043, Val Loss: 0.0040
#     Epoch 77: Train Loss: 0.0038, Val Loss: 0.0035
#     Epoch 78: Train Loss: 0.0033, Val Loss: 0.0030
#     Epoch 79: Train Loss: 0.0028, Val Loss: 0.0025
#     Epoch 80: Train Loss: 0.0024, Val Loss: 0.0021
#     Epoch 81: Train Loss: 0.0019, Val Loss: 0.0016
#     Epoch 82: Train Loss: 0.0015, Val Loss: 0.0013
#     Epoch 83: Train Loss: 0.0012, Val Loss: 0.0010
#     Epoch 84: Train Loss: 0.0009, Val Loss: 0.0007
#     Epoch 85: Train Loss: 0.0007, Val Loss: 0.0005
#     Epoch 86: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 87: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 88: Train Loss: 0.0004, Val Loss: 0.0005
#     Epoch 89: Train Loss: 0.0005, Val Loss: 0.0006
#     Epoch 90: Train Loss: 0.0006, Val Loss: 0.0007
#     Epoch 91: Train Loss: 0.0007, Val Loss: 0.0007
#     Epoch 92: Train Loss: 0.0008, Val Loss: 0.0008
#     Epoch 93: Train Loss: 0.0009, Val Loss: 0.0008
#     Epoch 94: Train Loss: 0.0009, Val Loss: 0.0008
#     Epoch 95: Train Loss: 0.0008, Val Loss: 0.0007
#     Epoch 96: Train Loss: 0.0008, Val Loss: 0.0006
#     Epoch 97: Train Loss: 0.0007, Val Loss: 0.0005
#     Epoch 98: Train Loss: 0.0006, Val Loss: 0.0004
#     Early stopping at epoch 98
#
# Training GRU - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 1
#     Epoch 1: Train Loss: 0.1065, Val Loss: 0.1026
#     Epoch 2: Train Loss: 0.1021, Val Loss: 0.0984
#     Epoch 3: Train Loss: 0.0979, Val Loss: 0.0943
#     Epoch 4: Train Loss: 0.0938, Val Loss: 0.0904
#     Epoch 5: Train Loss: 0.0899, Val Loss: 0.0865
#     Epoch 6: Train Loss: 0.0861, Val Loss: 0.0828
#     Epoch 7: Train Loss: 0.0824, Val Loss: 0.0792
#     Epoch 8: Train Loss: 0.0788, Val Loss: 0.0758
#     Epoch 9: Train Loss: 0.0753, Val Loss: 0.0724
#     Epoch 10: Train Loss: 0.0720, Val Loss: 0.0692
#     Epoch 11: Train Loss: 0.0688, Val Loss: 0.0660
#     Epoch 12: Train Loss: 0.0656, Val Loss: 0.0630
#     Epoch 13: Train Loss: 0.0626, Val Loss: 0.0600
#     Epoch 14: Train Loss: 0.0597, Val Loss: 0.0572
#     Epoch 15: Train Loss: 0.0569, Val Loss: 0.0545
#     Epoch 16: Train Loss: 0.0541, Val Loss: 0.0518
#     Epoch 17: Train Loss: 0.0515, Val Loss: 0.0493
#     Epoch 18: Train Loss: 0.0490, Val Loss: 0.0469
#     Epoch 19: Train Loss: 0.0466, Val Loss: 0.0445
#     Epoch 20: Train Loss: 0.0442, Val Loss: 0.0423
#     Epoch 21: Train Loss: 0.0420, Val Loss: 0.0401
#     Epoch 22: Train Loss: 0.0398, Val Loss: 0.0380
#     Epoch 23: Train Loss: 0.0378, Val Loss: 0.0360
#     Epoch 24: Train Loss: 0.0358, Val Loss: 0.0341
#     Epoch 25: Train Loss: 0.0339, Val Loss: 0.0323
#     Epoch 26: Train Loss: 0.0321, Val Loss: 0.0306
#     Epoch 27: Train Loss: 0.0304, Val Loss: 0.0290
#     Epoch 28: Train Loss: 0.0288, Val Loss: 0.0274
#     Epoch 29: Train Loss: 0.0273, Val Loss: 0.0260
#     Epoch 30: Train Loss: 0.0258, Val Loss: 0.0246
#     Epoch 31: Train Loss: 0.0245, Val Loss: 0.0234
#     Epoch 32: Train Loss: 0.0232, Val Loss: 0.0222
#     Epoch 33: Train Loss: 0.0220, Val Loss: 0.0211
#     Epoch 34: Train Loss: 0.0209, Val Loss: 0.0201
#     Epoch 35: Train Loss: 0.0199, Val Loss: 0.0191
#     Epoch 36: Train Loss: 0.0190, Val Loss: 0.0183
#     Epoch 37: Train Loss: 0.0182, Val Loss: 0.0175
#     Epoch 38: Train Loss: 0.0174, Val Loss: 0.0168
#     Epoch 39: Train Loss: 0.0167, Val Loss: 0.0162
#     Epoch 40: Train Loss: 0.0161, Val Loss: 0.0157
#     Epoch 41: Train Loss: 0.0156, Val Loss: 0.0152
#     Epoch 42: Train Loss: 0.0151, Val Loss: 0.0148
#     Epoch 43: Train Loss: 0.0148, Val Loss: 0.0145
#     Epoch 44: Train Loss: 0.0144, Val Loss: 0.0142
#     Epoch 45: Train Loss: 0.0141, Val Loss: 0.0140
#     Epoch 46: Train Loss: 0.0139, Val Loss: 0.0138
#     Epoch 47: Train Loss: 0.0137, Val Loss: 0.0136
#     Epoch 48: Train Loss: 0.0136, Val Loss: 0.0135
#     Epoch 49: Train Loss: 0.0135, Val Loss: 0.0134
#     Epoch 50: Train Loss: 0.0134, Val Loss: 0.0134
#     Epoch 51: Train Loss: 0.0134, Val Loss: 0.0133
#     Epoch 52: Train Loss: 0.0133, Val Loss: 0.0133
#     Epoch 53: Train Loss: 0.0133, Val Loss: 0.0132
#     Epoch 54: Train Loss: 0.0133, Val Loss: 0.0132
#     Epoch 55: Train Loss: 0.0132, Val Loss: 0.0132
#     Epoch 56: Train Loss: 0.0132, Val Loss: 0.0131
#     Epoch 57: Train Loss: 0.0131, Val Loss: 0.0131
#     Epoch 58: Train Loss: 0.0131, Val Loss: 0.0130
#     Epoch 59: Train Loss: 0.0130, Val Loss: 0.0129
#     Epoch 60: Train Loss: 0.0129, Val Loss: 0.0128
#     Epoch 61: Train Loss: 0.0128, Val Loss: 0.0127
#     Epoch 62: Train Loss: 0.0127, Val Loss: 0.0126
#     Epoch 63: Train Loss: 0.0126, Val Loss: 0.0125
#     Epoch 64: Train Loss: 0.0125, Val Loss: 0.0124
#     Epoch 65: Train Loss: 0.0124, Val Loss: 0.0122
#     Epoch 66: Train Loss: 0.0122, Val Loss: 0.0121
#     Epoch 67: Train Loss: 0.0121, Val Loss: 0.0120
#     Epoch 68: Train Loss: 0.0120, Val Loss: 0.0118
#     Epoch 69: Train Loss: 0.0118, Val Loss: 0.0117
#     Epoch 70: Train Loss: 0.0117, Val Loss: 0.0116
#     Epoch 71: Train Loss: 0.0116, Val Loss: 0.0114
#     Epoch 72: Train Loss: 0.0114, Val Loss: 0.0113
#     Epoch 73: Train Loss: 0.0113, Val Loss: 0.0112
#     Epoch 74: Train Loss: 0.0112, Val Loss: 0.0111
#     Epoch 75: Train Loss: 0.0111, Val Loss: 0.0110
#     Epoch 76: Train Loss: 0.0110, Val Loss: 0.0109
#     Epoch 77: Train Loss: 0.0108, Val Loss: 0.0107
#     Epoch 78: Train Loss: 0.0107, Val Loss: 0.0106
#     Epoch 79: Train Loss: 0.0106, Val Loss: 0.0105
#     Epoch 80: Train Loss: 0.0105, Val Loss: 0.0104
#     Epoch 81: Train Loss: 0.0104, Val Loss: 0.0103
#     Epoch 82: Train Loss: 0.0103, Val Loss: 0.0102
#     Epoch 83: Train Loss: 0.0102, Val Loss: 0.0101
#     Epoch 84: Train Loss: 0.0101, Val Loss: 0.0100
#     Epoch 85: Train Loss: 0.0100, Val Loss: 0.0099
#     Epoch 86: Train Loss: 0.0099, Val Loss: 0.0098
#     Epoch 87: Train Loss: 0.0097, Val Loss: 0.0096
#     Epoch 88: Train Loss: 0.0096, Val Loss: 0.0095
#     Epoch 89: Train Loss: 0.0095, Val Loss: 0.0094
#     Epoch 90: Train Loss: 0.0094, Val Loss: 0.0093
#     Epoch 91: Train Loss: 0.0093, Val Loss: 0.0092
#     Epoch 92: Train Loss: 0.0092, Val Loss: 0.0090
#     Epoch 93: Train Loss: 0.0090, Val Loss: 0.0089
#     Epoch 94: Train Loss: 0.0089, Val Loss: 0.0088
#     Epoch 95: Train Loss: 0.0088, Val Loss: 0.0087
#     Epoch 96: Train Loss: 0.0087, Val Loss: 0.0086
#     Epoch 97: Train Loss: 0.0085, Val Loss: 0.0084
#     Epoch 98: Train Loss: 0.0084, Val Loss: 0.0083
#     Epoch 99: Train Loss: 0.0083, Val Loss: 0.0082
#     Epoch 100: Train Loss: 0.0082, Val Loss: 0.0080
#
# Training GRU - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 2
#     Epoch 1: Train Loss: 0.0670, Val Loss: 0.0627
#     Epoch 2: Train Loss: 0.0632, Val Loss: 0.0590
#     Epoch 3: Train Loss: 0.0596, Val Loss: 0.0556
#     Epoch 4: Train Loss: 0.0562, Val Loss: 0.0523
#     Epoch 5: Train Loss: 0.0530, Val Loss: 0.0492
#     Epoch 6: Train Loss: 0.0499, Val Loss: 0.0463
#     Epoch 7: Train Loss: 0.0471, Val Loss: 0.0436
#     Epoch 8: Train Loss: 0.0444, Val Loss: 0.0411
#     Epoch 9: Train Loss: 0.0419, Val Loss: 0.0387
#     Epoch 10: Train Loss: 0.0396, Val Loss: 0.0365
#     Epoch 11: Train Loss: 0.0374, Val Loss: 0.0345
#     Epoch 12: Train Loss: 0.0354, Val Loss: 0.0327
#     Epoch 13: Train Loss: 0.0336, Val Loss: 0.0310
#     Epoch 14: Train Loss: 0.0319, Val Loss: 0.0294
#     Epoch 15: Train Loss: 0.0304, Val Loss: 0.0280
#     Epoch 16: Train Loss: 0.0290, Val Loss: 0.0267
#     Epoch 17: Train Loss: 0.0277, Val Loss: 0.0256
#     Epoch 18: Train Loss: 0.0266, Val Loss: 0.0245
#     Epoch 19: Train Loss: 0.0256, Val Loss: 0.0236
#     Epoch 20: Train Loss: 0.0246, Val Loss: 0.0228
#     Epoch 21: Train Loss: 0.0238, Val Loss: 0.0221
#     Epoch 22: Train Loss: 0.0231, Val Loss: 0.0214
#     Epoch 23: Train Loss: 0.0225, Val Loss: 0.0209
#     Epoch 24: Train Loss: 0.0220, Val Loss: 0.0204
#     Epoch 25: Train Loss: 0.0215, Val Loss: 0.0200
#     Epoch 26: Train Loss: 0.0211, Val Loss: 0.0197
#     Epoch 27: Train Loss: 0.0208, Val Loss: 0.0194
#     Epoch 28: Train Loss: 0.0205, Val Loss: 0.0191
#     Epoch 29: Train Loss: 0.0203, Val Loss: 0.0189
#     Epoch 30: Train Loss: 0.0200, Val Loss: 0.0187
#     Epoch 31: Train Loss: 0.0199, Val Loss: 0.0186
#     Epoch 32: Train Loss: 0.0197, Val Loss: 0.0184
#     Epoch 33: Train Loss: 0.0196, Val Loss: 0.0183
#     Epoch 34: Train Loss: 0.0194, Val Loss: 0.0182
#     Epoch 35: Train Loss: 0.0193, Val Loss: 0.0181
#     Epoch 36: Train Loss: 0.0192, Val Loss: 0.0179
#     Epoch 37: Train Loss: 0.0191, Val Loss: 0.0178
#     Epoch 38: Train Loss: 0.0189, Val Loss: 0.0177
#     Epoch 39: Train Loss: 0.0188, Val Loss: 0.0176
#     Epoch 40: Train Loss: 0.0187, Val Loss: 0.0174
#     Epoch 41: Train Loss: 0.0185, Val Loss: 0.0173
#     Epoch 42: Train Loss: 0.0183, Val Loss: 0.0171
#     Epoch 43: Train Loss: 0.0182, Val Loss: 0.0170
#     Epoch 44: Train Loss: 0.0180, Val Loss: 0.0168
#     Epoch 45: Train Loss: 0.0179, Val Loss: 0.0166
#     Epoch 46: Train Loss: 0.0177, Val Loss: 0.0165
#     Epoch 47: Train Loss: 0.0175, Val Loss: 0.0163
#     Epoch 48: Train Loss: 0.0173, Val Loss: 0.0162
#     Epoch 49: Train Loss: 0.0172, Val Loss: 0.0160
#     Epoch 50: Train Loss: 0.0170, Val Loss: 0.0158
#     Epoch 51: Train Loss: 0.0168, Val Loss: 0.0157
#     Epoch 52: Train Loss: 0.0167, Val Loss: 0.0155
#     Epoch 53: Train Loss: 0.0165, Val Loss: 0.0154
#     Epoch 54: Train Loss: 0.0163, Val Loss: 0.0153
#     Epoch 55: Train Loss: 0.0162, Val Loss: 0.0151
#     Epoch 56: Train Loss: 0.0160, Val Loss: 0.0150
#     Epoch 57: Train Loss: 0.0159, Val Loss: 0.0148
#     Epoch 58: Train Loss: 0.0157, Val Loss: 0.0147
#     Epoch 59: Train Loss: 0.0156, Val Loss: 0.0146
#     Epoch 60: Train Loss: 0.0155, Val Loss: 0.0145
#     Epoch 61: Train Loss: 0.0153, Val Loss: 0.0143
#     Epoch 62: Train Loss: 0.0152, Val Loss: 0.0142
#     Epoch 63: Train Loss: 0.0151, Val Loss: 0.0141
#     Epoch 64: Train Loss: 0.0149, Val Loss: 0.0140
#     Epoch 65: Train Loss: 0.0148, Val Loss: 0.0138
#     Epoch 66: Train Loss: 0.0147, Val Loss: 0.0137
#     Epoch 67: Train Loss: 0.0145, Val Loss: 0.0136
#     Epoch 68: Train Loss: 0.0144, Val Loss: 0.0135
#     Epoch 69: Train Loss: 0.0143, Val Loss: 0.0133
#     Epoch 70: Train Loss: 0.0141, Val Loss: 0.0132
#     Epoch 71: Train Loss: 0.0140, Val Loss: 0.0131
#     Epoch 72: Train Loss: 0.0139, Val Loss: 0.0130
#     Epoch 73: Train Loss: 0.0137, Val Loss: 0.0128
#     Epoch 74: Train Loss: 0.0136, Val Loss: 0.0127
#     Epoch 75: Train Loss: 0.0135, Val Loss: 0.0126
#     Epoch 76: Train Loss: 0.0133, Val Loss: 0.0124
#     Epoch 77: Train Loss: 0.0132, Val Loss: 0.0123
#     Epoch 78: Train Loss: 0.0130, Val Loss: 0.0122
#     Epoch 79: Train Loss: 0.0129, Val Loss: 0.0120
#     Epoch 80: Train Loss: 0.0128, Val Loss: 0.0119
#     Epoch 81: Train Loss: 0.0126, Val Loss: 0.0118
#     Epoch 82: Train Loss: 0.0125, Val Loss: 0.0116
#     Epoch 83: Train Loss: 0.0123, Val Loss: 0.0115
#     Epoch 84: Train Loss: 0.0122, Val Loss: 0.0114
#     Epoch 85: Train Loss: 0.0120, Val Loss: 0.0112
#     Epoch 86: Train Loss: 0.0119, Val Loss: 0.0111
#     Epoch 87: Train Loss: 0.0118, Val Loss: 0.0110
#     Epoch 88: Train Loss: 0.0116, Val Loss: 0.0108
#     Epoch 89: Train Loss: 0.0115, Val Loss: 0.0107
#     Epoch 90: Train Loss: 0.0113, Val Loss: 0.0105
#     Epoch 91: Train Loss: 0.0112, Val Loss: 0.0104
#     Epoch 92: Train Loss: 0.0110, Val Loss: 0.0103
#     Epoch 93: Train Loss: 0.0109, Val Loss: 0.0101
#     Epoch 94: Train Loss: 0.0107, Val Loss: 0.0100
#     Epoch 95: Train Loss: 0.0106, Val Loss: 0.0098
#     Epoch 96: Train Loss: 0.0104, Val Loss: 0.0097
#     Epoch 97: Train Loss: 0.0103, Val Loss: 0.0096
#     Epoch 98: Train Loss: 0.0101, Val Loss: 0.0094
#     Epoch 99: Train Loss: 0.0100, Val Loss: 0.0093
#     Epoch 100: Train Loss: 0.0098, Val Loss: 0.0091
#
# Training GRU - Hidden Size: 16, Num Layers: 1, Learning Rate: 0.001 - Fold 3
#     Epoch 1: Train Loss: 0.0224, Val Loss: 0.0231
#     Epoch 2: Train Loss: 0.0218, Val Loss: 0.0228
#     Epoch 3: Train Loss: 0.0215, Val Loss: 0.0225
#     Epoch 4: Train Loss: 0.0212, Val Loss: 0.0222
#     Epoch 5: Train Loss: 0.0210, Val Loss: 0.0220
#     Epoch 6: Train Loss: 0.0208, Val Loss: 0.0218
#     Epoch 7: Train Loss: 0.0206, Val Loss: 0.0216
#     Epoch 8: Train Loss: 0.0204, Val Loss: 0.0214
#     Epoch 9: Train Loss: 0.0202, Val Loss: 0.0211
#     Epoch 10: Train Loss: 0.0200, Val Loss: 0.0209
#     Epoch 11: Train Loss: 0.0197, Val Loss: 0.0207
#     Epoch 12: Train Loss: 0.0195, Val Loss: 0.0204
#     Epoch 13: Train Loss: 0.0193, Val Loss: 0.0202
#     Epoch 14: Train Loss: 0.0191, Val Loss: 0.0200
#     Epoch 15: Train Loss: 0.0189, Val Loss: 0.0198
#     Epoch 16: Train Loss: 0.0187, Val Loss: 0.0196
#     Epoch 17: Train Loss: 0.0185, Val Loss: 0.0194
#     Epoch 18: Train Loss: 0.0183, Val Loss: 0.0191
#     Epoch 19: Train Loss: 0.0181, Val Loss: 0.0189
#     Epoch 20: Train Loss: 0.0179, Val Loss: 0.0187
#     Epoch 21: Train Loss: 0.0177, Val Loss: 0.0185
#     Epoch 22: Train Loss: 0.0174, Val Loss: 0.0182
#     Epoch 23: Train Loss: 0.0172, Val Loss: 0.0180
#     Epoch 24: Train Loss: 0.0170, Val Loss: 0.0178
#     Epoch 25: Train Loss: 0.0168, Val Loss: 0.0176
#     Epoch 26: Train Loss: 0.0166, Val Loss: 0.0173
#     Epoch 27: Train Loss: 0.0164, Val Loss: 0.0171
#     Epoch 28: Train Loss: 0.0162, Val Loss: 0.0169
#     Epoch 29: Train Loss: 0.0160, Val Loss: 0.0167
#     Epoch 30: Train Loss: 0.0157, Val Loss: 0.0164
#     Epoch 31: Train Loss: 0.0155, Val Loss: 0.0162
#     Epoch 32: Train Loss: 0.0153, Val Loss: 0.0159
#     Epoch 33: Train Loss: 0.0151, Val Loss: 0.0157
#     Epoch 34: Train Loss: 0.0148, Val Loss: 0.0155
#     Epoch 35: Train Loss: 0.0146, Val Loss: 0.0152
#     Epoch 36: Train Loss: 0.0144, Val Loss: 0.0150
#     Epoch 37: Train Loss: 0.0142, Val Loss: 0.0147
#     Epoch 38: Train Loss: 0.0139, Val Loss: 0.0145
#     Epoch 39: Train Loss: 0.0137, Val Loss: 0.0142
#     Epoch 40: Train Loss: 0.0134, Val Loss: 0.0140
#     Epoch 41: Train Loss: 0.0132, Val Loss: 0.0137
#     Epoch 42: Train Loss: 0.0130, Val Loss: 0.0134
#     Epoch 43: Train Loss: 0.0127, Val Loss: 0.0132
#     Epoch 44: Train Loss: 0.0125, Val Loss: 0.0129
#     Epoch 45: Train Loss: 0.0122, Val Loss: 0.0126
#     Epoch 46: Train Loss: 0.0119, Val Loss: 0.0124
#     Epoch 47: Train Loss: 0.0117, Val Loss: 0.0121
#     Epoch 48: Train Loss: 0.0114, Val Loss: 0.0118
#     Epoch 49: Train Loss: 0.0111, Val Loss: 0.0115
#     Epoch 50: Train Loss: 0.0109, Val Loss: 0.0112
#     Epoch 51: Train Loss: 0.0106, Val Loss: 0.0109
#     Epoch 52: Train Loss: 0.0103, Val Loss: 0.0106
#     Epoch 53: Train Loss: 0.0100, Val Loss: 0.0103
#     Epoch 54: Train Loss: 0.0097, Val Loss: 0.0100
#     Epoch 55: Train Loss: 0.0094, Val Loss: 0.0096
#     Epoch 56: Train Loss: 0.0091, Val Loss: 0.0093
#     Epoch 57: Train Loss: 0.0088, Val Loss: 0.0090
#     Epoch 58: Train Loss: 0.0085, Val Loss: 0.0086
#     Epoch 59: Train Loss: 0.0082, Val Loss: 0.0083
#     Epoch 60: Train Loss: 0.0078, Val Loss: 0.0079
#     Epoch 61: Train Loss: 0.0075, Val Loss: 0.0076
#     Epoch 62: Train Loss: 0.0072, Val Loss: 0.0072
#     Epoch 63: Train Loss: 0.0068, Val Loss: 0.0069
#     Epoch 64: Train Loss: 0.0065, Val Loss: 0.0065
#     Epoch 65: Train Loss: 0.0061, Val Loss: 0.0061
#     Epoch 66: Train Loss: 0.0058, Val Loss: 0.0057
#     Epoch 67: Train Loss: 0.0054, Val Loss: 0.0054
#     Epoch 68: Train Loss: 0.0051, Val Loss: 0.0050
#     Epoch 69: Train Loss: 0.0047, Val Loss: 0.0046
#     Epoch 70: Train Loss: 0.0043, Val Loss: 0.0042
#     Epoch 71: Train Loss: 0.0040, Val Loss: 0.0038
#     Epoch 72: Train Loss: 0.0036, Val Loss: 0.0034
#     Epoch 73: Train Loss: 0.0032, Val Loss: 0.0030
#     Epoch 74: Train Loss: 0.0029, Val Loss: 0.0027
#     Epoch 75: Train Loss: 0.0025, Val Loss: 0.0023
#     Epoch 76: Train Loss: 0.0022, Val Loss: 0.0020
#     Epoch 77: Train Loss: 0.0019, Val Loss: 0.0016
#     Epoch 78: Train Loss: 0.0015, Val Loss: 0.0013
#     Epoch 79: Train Loss: 0.0012, Val Loss: 0.0010
#     Epoch 80: Train Loss: 0.0010, Val Loss: 0.0008
#     Epoch 81: Train Loss: 0.0007, Val Loss: 0.0006
#     Epoch 82: Train Loss: 0.0005, Val Loss: 0.0004
#     Epoch 83: Train Loss: 0.0004, Val Loss: 0.0002
#     Epoch 84: Train Loss: 0.0002, Val Loss: 0.0002
#     Epoch 85: Train Loss: 0.0002, Val Loss: 0.0001
#     Epoch 86: Train Loss: 0.0001, Val Loss: 0.0001
#     Epoch 87: Train Loss: 0.0001, Val Loss: 0.0002
#     Epoch 88: Train Loss: 0.0002, Val Loss: 0.0002
#     Epoch 89: Train Loss: 0.0002, Val Loss: 0.0003
#     Epoch 90: Train Loss: 0.0003, Val Loss: 0.0004
#     Epoch 91: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 92: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 93: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 94: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 95: Train Loss: 0.0004, Val Loss: 0.0004
#     Epoch 96: Train Loss: 0.0004, Val Loss: 0.0003
#     Early stopping at epoch 96
# Test RMSE for RNN: 0.1755
# Test RMSE for LSTM: 0.5206
# Test RMSE for GRU: 0.3963
